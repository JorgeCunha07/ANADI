# %%
import pandas as pd
from scipy.stats import t
import numpy as np
import scipy.stats as stats

nutriCSV = pd.read_csv("nutri.csv", sep=';')
nutriCSV
# Out:
#     processo  sexo  peso_nascenca comprimento perimetro_cef
# 0          1     2           2440          46            33
# 1          2     2           2600          45            33
# 2          3     1           2700          48            33
# 3          4     1           2750          51
# 4          5     2           2800                        33
# 5          6     2           2850          48            35
# 6          7     1           2900          49            37
# 7          8     1           2900          48            35
# 8          9     1           3000          50            36
# 9         10     2           3000          48
# 10        11     1           3000          49            34
# 11        12     2           3000          50            35
# 12        13     2           3000          48            33
# 13        14     2           3000          49            35
# 14        15     2           3050          49            34
# ...

# %%
# Assumindo que a coluna de peso é 'Peso'
media_peso_2011 = 3400
t_stat, p_value = stats.ttest_1samp(nutriCSV['peso_nascenca'], media_peso_2011)
print('Statistiscs ',t_stat)
print('P-Value ', p_value)
# Out:
# Statistiscs  0.19515278412066875
# P-Value  0.8459673143133309
