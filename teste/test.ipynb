# %%
import pandas as pd
dados = pd.read_csv("census-income.csv" , delimiter="," , header=None ) # ler dados sem header

# %%
# para obter detalhes de uma função da biblioteca padrão do Python, por exemplo
# help(list)
# para obter detalhes de uma função da biblioteca Pandas, por exemplo
# help(pd.read_csv)
dados.head(n=5) # Mostra as primeiras n linhas ou print(dados.head(n=5))
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
dados.tail(n=4) # mostra as últimas n linhas
# Out:
#        0              1       2         3   4                    5   \
# 32557  40        Private  154374   HS-grad   9   Married-civ-spouse
# 32558  58        Private  151910   HS-grad   9              Widowed
# 32559  22        Private  201490   HS-grad   9        Never-married
# 32560  52   Self-emp-inc  287927   HS-grad   9   Married-civ-spouse
#
#                        6           7       8        9      10  11  12  \
# 32557   Machine-op-inspct     Husband   White     Male      0   0  40
# 32558        Adm-clerical   Unmarried   White   Female      0   0  40
# 32559        Adm-clerical   Own-child   White     Male      0   0  20
# 32560     Exec-managerial        Wife   White   Female  15024   0  40
#
#                    13      14
# 32557   United-States    >50K
# 32558   United-States   <=50K
# 32559   United-States   <=50K
# 32560   United-States    >50K

# %%
type(dados) # ver tipo
# Out:
# pandas.core.frame.DataFrame

# %%
print(dados.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       32561 non-null  int64
#  1   1       32561 non-null  object
#  2   2       32561 non-null  int64
#  3   3       32561 non-null  object
#  4   4       32561 non-null  int64
#  5   5       32561 non-null  object
#  6   6       32561 non-null  object
#  7   7       32561 non-null  object
#  8   8       32561 non-null  object
#  9   9       32561 non-null  object
#  10  10      32561 non-null  int64
#  11  11      32561 non-null  int64
#  12  12      32561 non-null  int64
#  13  13      32561 non-null  object
#  14  14      32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# None

# %%
print(dados.describe())
# Out:
#                  0             2             4             10            11  \
# count  32561.000000  3.256100e+04  32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05     10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05      2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04      1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05      9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05     10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05     12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06     16.000000  99999.000000   4356.000000
#
#                  12
# count  32561.000000
# mean      40.437456
# std       12.347429
# min        1.000000
# 25%       40.000000
# 50%       40.000000
# 75%       45.000000
# max       99.000000

# %%
#teste

# %%
dados.columns = ["age","workclass","fnlwgt","education",
"education_num","marital_status","occupation","relationship","race","sex",
"capital_gain","capital_loss","hours_per_week","native_country","X"]
dados.head(n=55)
# Out:
#     age         workclass  fnlwgt     education  education_num  \
# 0    39         State-gov   77516     Bachelors             13
# 1    50  Self-emp-not-inc   83311     Bachelors             13
# 2    38           Private  215646       HS-grad              9
# 3    53           Private  234721          11th              7
# 4    28           Private  338409     Bachelors             13
# 5    37           Private  284582       Masters             14
# 6    49           Private  160187           9th              5
# 7    52  Self-emp-not-inc  209642       HS-grad              9
# 8    31           Private   45781       Masters             14
# 9    42           Private  159449     Bachelors             13
# 10   37           Private  280464  Some-college             10
# 11   30         State-gov  141297     Bachelors             13
# 12   23           Private  122272     Bachelors             13
# 13   32           Private  205019    Assoc-acdm             12
# ...

# %%
dados['native_country']=dados['native_country'].str.strip()

# %%
# eliminar os espaços em branco da coluna 'native_country'
dados['native_country']=dados['native_country'].str.strip()
# verificação
dados['native_country'].unique()
# Out:
# array(['United-States', 'Cuba', 'Jamaica', 'India', '?', 'Mexico',
#        'South', 'Puerto-Rico', 'Honduras', 'England', 'Canada', 'Germany',
#        'Iran', 'Philippines', 'Italy', 'Poland', 'Columbia', 'Cambodia',
#        'Thailand', 'Ecuador', 'Laos', 'Taiwan', 'Haiti', 'Portugal',
#        'Dominican-Republic', 'El-Salvador', 'France', 'Guatemala',
#        'China', 'Japan', 'Yugoslavia', 'Peru',
#        'Outlying-US(Guam-USVI-etc)', 'Scotland', 'Trinadad&Tobago',
#        'Greece', 'Nicaragua', 'Vietnam', 'Hong', 'Ireland', 'Hungary',
#        'Holand-Netherlands'], dtype=object)

# %%
education_classes = dados['education'].unique()
education_classes
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
#retirar os espaços em branco a todas as colunas do DataFrame
dados = dados.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# verificação na coluna 'education'
dados['education'].unique()
# Out:
# array(['Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college',
#        'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school',
#        '5th-6th', '10th', '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
dados.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# X                 0
# dtype: int64

# %%
# substituição na coluna *'native_country'*, da string *'?'* pela constante *None*.
dados['native_country']=dados['native_country'].replace('?', None)

# %%
dados
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
dados_new=dados.drop(['workclass','education','marital_status','race'],axis = 1)
dados_new.head(n=3)
# Out:
#    age  fnlwgt  education_num         occupation   relationship   sex  \
# 0   39   77516             13       Adm-clerical  Not-in-family  Male
# 1   50   83311             13    Exec-managerial        Husband  Male
# 2   38  215646              9  Handlers-cleaners  Not-in-family  Male
#
#    capital_gain  capital_loss  hours_per_week native_country      X
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K

# %%
dados_30_35=dados[(dados['age'] >= 30) & (dados['age'] <= 35)]
dados_30_35.head(n=5)
# Out:
#     age  workclass  fnlwgt   education  education_num      marital_status  \
# 8    31    Private   45781     Masters             14       Never-married
# 11   30  State-gov  141297   Bachelors             13  Married-civ-spouse
# 13   32    Private  205019  Assoc-acdm             12       Never-married
# 15   34    Private  245487     7th-8th              4  Married-civ-spouse
# 17   32    Private  186824     HS-grad              9       Never-married
#
#            occupation   relationship                race     sex  \
# 8      Prof-specialty  Not-in-family               White  Female
# 11     Prof-specialty        Husband  Asian-Pac-Islander    Male
# 13              Sales  Not-in-family               Black    Male
# 15   Transport-moving        Husband  Amer-Indian-Eskimo    Male
# 17  Machine-op-inspct      Unmarried               White    Male
#
#     capital_gain  capital_loss  hours_per_week native_country      X
# ...

# %%
# Alternativamente usando o método .loc()
dados_30_35female=dados.loc[(dados['age'] >= 30) & (dados['age'] <= 35) & (dados['sex']=='Female')]
dados_30_35female.head(n=5)
# Out:
#      age  workclass  fnlwgt  education  education_num      marital_status  \
# 8     31    Private   45781    Masters             14       Never-married
# 71    31    Private  309974  Bachelors             13           Separated
# 93    30    Private  117747    HS-grad              9  Married-civ-spouse
# 108   31  Local-gov  189265    HS-grad              9       Never-married
# 145   31    Private  185814    HS-grad              9       Never-married
#
#            occupation   relationship                race     sex  \
# 8      Prof-specialty  Not-in-family               White  Female
# 71              Sales      Own-child               Black  Female
# 93              Sales           Wife  Asian-Pac-Islander  Female
# 108      Adm-clerical  Not-in-family               White  Female
# 145  Transport-moving      Unmarried               Black  Female
#
#      capital_gain  capital_loss  hours_per_week native_country      X
# ...

# %%
idade_media=dados["age"].mean()
print("idade média =", idade_media) # ou arredondando na 2ª casa decimal
print("idade média =", round(idade_media,2))
# Out:
# idade média = 38.58164675532078
# idade média = 38.58

# %%
import numpy as np
amostra = pd.Series([1,np.NaN,2,None,3,4])
print("média da amostra = " , amostra.mean())
# Out:
# média da amostra =  2.5

# %%
# Definir um dicionário
dici = { 'Column1': [1, 2, 3, 4],
         'Column2': [5, 6, 7, 8],
         'Column3': [9, 10, 11, 12]
    }

# Definir um Dataframe
df = pd.DataFrame(dici)

# Calcular a média de cada coluna do DataFrame
media_das_colunas = df.mean()

print("média das colunas =", media_das_colunas)
type(media_das_colunas)
# Out:
# média das colunas = Column1     2.5
# Column2     6.5
# Column3    10.5
# dtype: float64
# pandas.core.series.Series

# %%
# Criar uma serie
serie = pd.Series([1, 2, np.NaN, 4, 5, 9, 123])
# Calcular a mediana
mediana = serie.median()
print("Mediana = ", mediana)
# Out:
# Mediana =  4.5

# %%
dadosq = pd.Series([1, 2, 4, 4, 5, 9, 5, 8, 9, 13 ,3 ,5 ,6])
ordem=0.75
dadosq.quantile(q=ordem)
# Out:
# 8.0

# %%
def calcula_aiq(data):
 """
 Calcula a amplitude interquartil (AIQ) de data
 Parametros:
 - data: pandas.Series, pandas.DataFrame
 Retorna:
 - aiq: amplitude interquartil

 """
 Q1 = data.quantile(q=0.25)
 Q3 = data.quantile(q=0.75)
 aiq = Q3-Q1
 return aiq
dadosq_aiq=calcula_aiq(dadosq)
print("Amplitude interquartil =", dadosq_aiq)
# Out:
# Amplitude interquartil = 4.0

# %%
dadosq.var()
# Out:
# 10.897435897435898

# %%
dadosq.std()
# Out:
# 3.301126458867624

# %%
def coef_assimetria(data):
 n = len(data)
 media=data.mean()
 s = data.std()

 a3=n/((n-1)*(n-2))*1/s**3*((data-media)**3).sum()

 return a3
print(coef_assimetria(dadosq))
print(dadosq.skew())
# Out:
# 0.7969083341533586
# 0.7969083341533587

# %%
import numpy as np
datak=np.random.normal(size=(4,1))

# %%
#print(type(datak))
#print(datak.size)
Dframe = pd.DataFrame(datak,columns=["col1"])
print(f"curtose :",Dframe["col1"].kurt())
# Out:
# curtose : -5.428329168000561

# %%
freq_absolutas = pd.crosstab(dados['education'],'numero de pessoas')
print(freq_absolutas)
# Out:
# col_0         numero de pessoas
# education
# 10th                        933
# 11th                       1175
# 12th                        433
# 1st-4th                     168
# 5th-6th                     333
# 7th-8th                     646
# 9th                         514
# Assoc-acdm                 1067
# Assoc-voc                  1382
# Bachelors                  5355
# Doctorate                   413
# HS-grad                   10501
# Masters                    1723
# Preschool                    51
# Prof-school                 576
# Some-college               7291

# %%
freq_relativas=pd.crosstab(dados['education'],'numero de pessoas',normalize=True)
# ou alternativamente
#freq_relativas= freq_absolutas/len(dados['education'])

# %%
print(freq_relativas)
# Out:
# col_0         numero de pessoas
# education
# 10th                   0.028654
# 11th                   0.036086
# 12th                   0.013298
# 1st-4th                0.005160
# 5th-6th                0.010227
# 7th-8th                0.019840
# 9th                    0.015786
# Assoc-acdm             0.032769
# Assoc-voc              0.042443
# Bachelors              0.164461
# Doctorate              0.012684
# HS-grad                0.322502
# Masters                0.052916
# Preschool              0.001566
# Prof-school            0.017690
# Some-college           0.223918

# %%
print(freq_relativas.sum())
# Out:
# col_0
# numero de pessoas    1.0
# dtype: float64

# %%
freq_table = pd.crosstab(dados['education'], dados['sex'])
print(freq_table)
type(freq_table)
# Out:
# sex           Female  Male
# education
# 10th             295   638
# 11th             432   743
# 12th             144   289
# 1st-4th           46   122
# 5th-6th           84   249
# 7th-8th          160   486
# 9th              144   370
# Assoc-acdm       421   646
# Assoc-voc        500   882
# Bachelors       1619  3736
# Doctorate         86   327
# HS-grad         3390  7111
# Masters          536  1187
# Preschool         16    35
# Prof-school       92   484
# Some-college    2806  4485
# pandas.core.frame.DataFrame

# %%
freq_absolutas.plot.bar(x=None, y=None)
# Out:
# <Axes: xlabel='education'>

# %%
freq_table.plot.bar(x=None, y=None)
# Out:
# <Axes: xlabel='education'>

# %%
dfsex=dados['sex']
freq_bysex = pd.crosstab(dfsex,'numero')
#freq_relbysex=freq_bysex/len(dados['sex'])
freq_relbysex=pd.crosstab(dfsex,'numero',normalize=True)
freq_relbysex['numero'].plot(kind='pie', y='Value')
# Out:
# <Axes: ylabel='numero'>

# %%
dados.boxplot(by =None, column =['age'], grid = False)
dados.boxplot(by ='sex', column =['age'], grid = True)
# Out:
# <Axes: title={'center': 'age'}, xlabel='sex'>

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(81) # seed 81
num_aleat = np.random.normal(loc=0, scale=1,size=2000) # numpy.ndarray
# help(np.random.normal)
num_aleatorios = pd.DataFrame({'valores': num_aleat}) # pandas.DataFrame
#
num_aleatorios['valores'].plot(kind='hist', bins=30, edgecolor='black', color='skyblue')
#
plt.title('Histograma de números aleatórios')
plt.xlabel('Valores')
plt.ylabel('Frequencia')
plt.show()

# %% [markdown]
# # Calcular o número de bins usando a Regra de Sturges
# N = len(dados)
# k = math.ceil(1 + np.log2(N))
